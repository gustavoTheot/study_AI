# %%
import pandas as pd

from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LinearRegression

# %%
# Possui valores de casas na california
housing = datasets.fetch_california_housing()

# %%
housing
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#            37.88      , -122.23      ],
#         [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#            37.86      , -122.22      ],
#         [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#            37.85      , -122.24      ],
#         ...,
#         [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#            39.43      , -121.22      ],
#         [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#            39.43      , -121.32      ],
#         [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#            39.37      , -121.24      ]], shape=(20640, 8)),
#  'target': array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894], shape=(20640,)),
#  'frame': None,
#  'target_names': ['MedHouseVal'],
#  'feature_names': ['MedInc',
#   'HouseAge',
#   'AveRooms',
#   'AveBedrms',
#   'Population',
# ...

# %%
# Pega os dados e coloca em um dataframe, pegando os dados que estão em housing.data e as colunas que estão em housing.feature_names
df = pd.DataFrame(housing.data, columns=housing.feature_names)

# %%
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
# Mostra a descrição do dataset
print(housing.DESCR)
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 20640
#
# :Number of Attributes: 8 numeric, predictive attributes and the target
#
# :Attribute Information:
#     - MedInc        median income in block group
#     - HouseAge      median house age in block group
#     - AveRooms      average number of rooms per household
#     - AveBedrms     average number of bedrooms per household
#     - Population    block group population
#     - AveOccup      average number of household members
#     - Latitude      block group latitude
#     - Longitude     block group longitude
#
# :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# https://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html
#
# The target variable is the median house value for California districts,
# expressed in hundreds of thousands of dollars ($100,000).
#
# ...

# %%
# Pega os dados de target e coloca em um dataframe, pegando os dados que estão em housing.target e a coluna 'MedHouseVal'
dfTarget = pd.DataFrame(housing.target, columns=housing.target_names)

# %%
# Mostra o dataframe de target
dfTarget.head()
# Out:
#    MedHouseVal
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422

# %%
X = df
Y = dfTarget

# %%
# Divide os dados em treino e teste, usando a função train_test_split do sklearn, passando os dados de X e Y, o tamanho do teste (20%) e a random_state (42)
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=123)

# %%
X_train
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 9950   4.5694      28.0  6.219512   1.030488       504.0  3.073171     38.38
# 3547   5.6392      18.0  5.951644   1.034816      3010.0  2.911025     34.26
# 4448   1.7292      47.0  3.628032   1.032345      1452.0  3.913747     34.07
# 6984   4.6226      36.0  5.126238   0.985149       988.0  2.445545     33.96
# 4432   2.4375      49.0  4.024390   0.942073      1405.0  4.283537     34.08
# ...       ...       ...       ...        ...         ...       ...       ...
# 7763   3.6389      36.0  5.584615   1.115385       490.0  3.769231     33.91
# 15377  4.5391      14.0  6.016688   1.017972      2436.0  3.127086     33.37
# 17730  5.6306       5.0  5.958393   1.031564      2435.0  3.493544     37.33
# 15725  3.8750      44.0  4.739264   1.024540       561.0  1.720859     37.78
# 19966  2.5156      20.0  5.491379   1.117816      1241.0  3.566092     36.21
#
#        Longitude
# 9950     -122.33
# ...

# %%
X_test
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 19121  3.7917      40.0  4.959799   1.030151      1039.0  2.610553     38.24
# 20019  4.0217       9.0  5.804577   1.000000      1749.0  3.079225     36.09
# 15104  4.0882      12.0  5.360360   1.070571      3321.0  4.986486     32.85
# 3720   2.2377      27.0  3.376582   1.023207      3403.0  3.589662     34.20
# 8938   4.4211      41.0  5.656904   1.165272      1047.0  2.190377     34.01
# ...       ...       ...       ...        ...         ...       ...       ...
# 313    2.7159      45.0  5.306590   1.126074      1132.0  3.243553     37.77
# 4596   1.4413      41.0  2.547009   1.102564      2931.0  4.175214     34.05
# 16287  1.6900      31.0  5.290323   1.154839       576.0  3.716129     37.91
# 5771   2.6729      22.0  4.037433   1.135472      1684.0  3.001783     34.15
# 18254  5.5385      36.0  5.048780   0.956098       475.0  2.317073     37.39
#
#        Longitude
# 19121    -122.64
# ...

# %%
y_train
# Out:
#        MedHouseVal
# 9950         2.875
# 3547         2.715
# 4448         1.917
# 6984         2.197
# 4432         1.140
# ...            ...
# 7763         1.676
# 15377        1.809
# 17730        2.862
# 15725        4.125
# 19966        0.593
#
# [16512 rows x 1 columns]

# %%
y_test
# Out:
#        MedHouseVal
# 19121        1.516
# 20019        0.992
# 15104        1.345
# 3720         2.317
# 8938         4.629
# ...            ...
# 313          1.014
# 4596         1.589
# 16287        0.659
# 5771         2.171
# 18254        3.590
#
# [4128 rows x 1 columns]

# %%
# Esalona os dados, fazendo com que todas as variáveis númericas tenha a mesma proporção de valores, usando a função StandardScaler do sklearn, passando os dados
scaler = StandardScaler()

# %%
# Escale os dados de treino e teste, usando a função fit_transform do scaler, passando os dados de treino e teste
X_train_Scaled = scaler.fit_transform(X_train)
X_test_Scaled = scaler.fit_transform(X_test)

# %%
X_train_Scaled
# Out:
# array([[ 3.67714244e-01, -4.53761462e-02,  3.16164288e-01, ...,
#          7.95197399e-04,  1.28942183e+00, -1.38119534e+00],
#        [ 9.30744845e-01, -8.40168684e-01,  2.09903463e-01, ...,
#         -1.44664485e-02, -6.40792431e-01,  4.83377271e-01],
#        [-1.12706938e+00,  1.46472968e+00, -7.11852087e-01, ...,
#          7.99128099e-02, -7.29807166e-01,  6.78332584e-01],
#        ...,
#        [ 9.26218707e-01, -1.87339898e+00,  2.12580734e-01, ...,
#          4.03620114e-02,  7.97498292e-01, -1.09626065e+00],
#        [ 2.25485873e-03,  1.22629191e+00, -2.71036722e-01, ...,
#         -1.26488590e-01,  1.00832267e+00, -1.43618273e+00],
#        [-7.13190832e-01, -6.81210176e-01,  2.73206265e-02, ...,
#          4.71904727e-02,  2.72779852e-01,  2.43432270e-01]],
#       shape=(16512, 8))

# %%
# Modelagem, onde se constroi o modelo de regressão linear, usando a função LinearRegression do sklearn, passando os dados de treino escalonados e os dados de treino de target

# Treina essa IA com o X_train_Scaled e o y_train, usando a função fit do reg, passando os dados de treino escalonados e os dados de treino de target
reg = LinearRegression().fit(X_train_Scaled, y_train)

# %%
result = reg.predict(X_test_Scaled)

# %%
result
# Out:
# array([[2.36963052],
#        [1.42164175],
#        [2.03935223],
#        ...,
#        [0.97891953],
#        [1.75012751],
#        [3.15660826]], shape=(4128, 1))

# %%
# Avaliação do modelo, usando a função score do reg, passando os dados de teste escalonados e os dados de teste de target
reg.score(X_test_Scaled, y_test)
# Out:
# 0.6113273240072044
